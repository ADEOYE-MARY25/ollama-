# %%
import torch
from torch import nn # nn contains all of PyTorch's building blocks for neural networks
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import torch
#       2 from torch import nn # nn contains all of PyTorch's building blocks for neural networks
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'torch'

# %%
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
#  Get the  python number within a tensor (only works with one-element tensors)
scalar.item()
# Out:
# 7

# %%
scalar.ndim
# Out:
# 0

# %%
import numpy as np

# %%
one = np.array(1)
print(one.shape)
# Out:
# ()

# %%
print(one.ndim)
# Out:
# 0

# %%
# Vector
vector = torch.tensor([7, 7])
vector
# Out:
# tensor([7, 7])

# %%
# check the number of dimensions of vectors
vector.ndim
# Out:
# 1

# %%
vector.shape
# Out:
# torch.Size([2])

# %%
# Matrix
MATRIX = torch.tensor([[7, 8],
                       [9, 10]])
MATRIX
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
# Check number of dimension
MATRIX.ndim
# Out:
# 2

# %%
MATRIX.shape
# Out:
# torch.Size([2, 2])

# %%
# Tensor
TENSOR = torch.tensor([[[1, 2, 3],
                        [3, 6, 9],
                        [2, 4, 5]]])
TENSOR
# Out:
# tensor([[[1, 2, 3],
#          [3, 6, 9],
#          [2, 4, 5]]])

# %%
TENSOR.shape
# Out:
# torch.Size([1, 3, 3])

# %%
TENSOR.ndim
# Out:
# 3

# %%
# Create a random tensor of size (3, 4)
random_tensor = torch.rand(3,5)
random_tensor
# Out:
# tensor([[0.8167, 0.6465, 0.4906, 0.3710, 0.6024],
#         [0.6106, 0.1816, 0.5661, 0.4832, 0.5351],
#         [0.9914, 0.0537, 0.2317, 0.7766, 0.6513]])

# %%
random_tensor.dtype
# Out:
# torch.float32

# %%
# Create a random tensor of size (224, 224, 3)
random_image_size_tensor = torch.rand(size=(224, 224, 3))
random_image_size_tensor.shape, random_image_size_tensor.ndim
# Out:
# (torch.Size([224, 224, 3]), 3)

# %%
# use torch.arrange(), torch.range() is deprecated
zero_to_ten_deprecated = torch.range(0, 10) # Note: this may return an error in the future
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # use torch.arrange(), torch.range() is deprecated
# ----> 2 zero_to_ten_deprecated = torch.range(0, 10) # Note: this may return an error in the future
#
# NameError: name 'torch' is not defined
